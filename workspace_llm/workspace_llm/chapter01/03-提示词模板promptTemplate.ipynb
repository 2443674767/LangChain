# %%
from langchain_core.prompts import PromptTemplate

#1、创建PromptTemplate的实例
#参数中必须要指明：input_variables 、template
prompt_template = PromptTemplate(
    template="你是一个{role},你的名字叫{name}",
    input_variables=["role","name"],
)

# print(prompt_template)


#2、填充实例中的变量。暂且使用format()
prompt = prompt_template.format(role="人工智能专家",name="小智")

print(prompt)
# Out:
# 你是一个人工智能专家,你的名字叫小智

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。",
    input_variables=["product", "aspect1", "aspect2"])

#使用模板生成提示词
prompt_1 = template.format(product="智能手机", aspect1="电池续航", aspect2="拍照质量")
prompt_2 = template.format(product="笔记本电脑", aspect1="处理速度", aspect2="便携性")

print("提示词1:",prompt_1)
print("提示词2:",prompt_2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.prompts import PromptTemplate
#       3 #定义多变量模板
#       4 template = PromptTemplate(
#       5     template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。",
#       6     input_variables=["product", "aspect1", "aspect2"])
#
# ModuleNotFoundError: No module named 'langchain.prompts'

# %%
from langchain_core.prompts import PromptTemplate


#1、创建PromptTemplate的实例
prompt_template = PromptTemplate.from_template(template="你是一个{role},你的名字叫{name}")

print(prompt_template)


#2、填充实例中的变量。暂且使用format()
prompt = prompt_template.format(role="人工智能专家",name="小智")

print(prompt)
# Out:
# input_variables=['name', 'role'] input_types={} partial_variables={} template='你是一个{role},你的名字叫{name}'
# 你是一个人工智能专家,你的名字叫小智

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate.from_template(template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。")

#使用模板生成提示词
prompt_1 = template.format(product="智能手机", aspect1="电池续航", aspect2="拍照质量")

print(prompt_1)
# Out:
# 请评价智能手机的优缺点，包括电池续航和拍照质量。

# %%
#1.导入相关的包
from langchain_core.prompts import PromptTemplate

# 2.定义提示词模版对象
text = """
Tell me a joke
"""

prompt_template = PromptTemplate.from_template(text)
# 3.默认使用f-string进行格式化（返回格式好的字符串）
prompt = prompt_template.format()
print(prompt)
# Out:
# Tell me a joke

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。",
    partial_variables={"aspect1":"电池续航"}
)

#使用模板生成提示词
prompt_1 = template.format(product="智能手机",aspect2="拍照质量")

print(prompt_1)
# Out:
# 请评价智能手机的优缺点，包括电池续航和拍照质量。

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。",
    input_variables=["product", "aspect1", "aspect2"],
    partial_variables={"aspect1":"电池续航","aspect2":"拍照质量"}
)

#使用模板生成提示词
prompt_1 = template.format(product="智能手机")

print("提示词1:",prompt_1)
# Out:
# 提示词1: 请评价智能手机的优缺点，包括电池续航和拍照质量。

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。",
    input_variables=["product", "aspect1", "aspect2"],
    # partial_variables={"aspect1":"电池续航","aspect2":"拍照质量"}
)

# partial()调用完以后，不会对调用者这个模板对象产生影响；而其返回值是一个新的模板
template1 = template.partial(aspect1="电池续航",aspect2="拍照质量")

#使用模板生成提示词
prompt_1 = template1.format(product="智能手机")

print("提示词1:",prompt_1)
# Out:
# 提示词1: 请评价智能手机的优缺点，包括电池续航和拍照质量。

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。",
    input_variables=["product", "aspect1", "aspect2"],
).partial(aspect1="电池续航",aspect2="拍照质量")

#使用模板生成提示词
prompt_1 = template.format(product="智能手机")

print("提示词1:",prompt_1)
# Out:
# 提示词1: 请评价智能手机的优缺点，包括电池续航和拍照质量。

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = (PromptTemplate
            .from_template(template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。")
            .partial(aspect1="电池续航",aspect2="拍照质量"))

#使用模板生成提示词
prompt_1 = template.format(product="智能手机")

print("提示词1:",prompt_1)
# Out:
# 提示词1: 请评价智能手机的优缺点，包括电池续航和拍照质量。

# %% [markdown]
# 组合提示词

# %%
from langchain_core.prompts import PromptTemplate

template = (
    PromptTemplate.from_template(template = "Tell me a joke about {topic}")
    + ", make it funny"
    + "\n\nand in {language}"
)

prompt = template.format(topic="sports", language="spanish")
print(prompt)
# Out:
# Tell me a joke about sports, make it funny
#
# and in spanish

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。")

#使用模板生成提示词
prompt_1 = template.format(product="智能手机", aspect1="电池续航", aspect2="拍照质量")

print(prompt_1)
print(type(prompt_1))
# Out:
# 请评价智能手机的优缺点，包括电池续航和拍照质量。
# <class 'str'>

# %%
from langchain.prompts import PromptTemplate

#定义多变量模板
template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。")

#使用模板生成提示词
# prompt_1 = template.format(product="智能手机", aspect1="电池续航", aspect2="拍照质量")
prompt_1 = template.invoke(input={"product":"智能手机","aspect1":"电池续航","aspect2":"拍照质量"})

print(prompt_1)
print(type(prompt_1))  #返回值类型：PromptValue
# Out:
# text='请评价智能手机的优缺点，包括电池续航和拍照质量。'
# <class 'langchain_core.prompt_values.StringPromptValue'>

# %% [markdown]
# 结合大模型的使用

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

#加载配置文件
dotenv.load_dotenv()


os.environ["OPENAI_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DASHSCOPE_BASE_URL")


########核心代码############
chat_model = ChatOpenAI(model="qwen-turbo",
                        temperature=0.7,    # 1=创造力
                        max_tokens=300,)     # 最大数量


# 生成提示词模板
template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。")

# 给模板的变量赋值
prompt = template.invoke(input={"product":"智能手机","aspect1":"电池续航","aspect2":"拍照质量"})

# 调用大模型，将提示词传入
response= chat_model.invoke(prompt)
print(response)
print(type(response))
# Out:
# content='智能手机作为现代生活中不可或缺的工具，其优缺点在多个方面都有显著体现。以下从**电池续航**和**拍照质量**两个主要方面，结合整体优缺点进行评价：\n\n---\n\n## 一、智能手机的优点\n\n### 1. **便携性与多功能性**\n- 智能手机集成了通讯、上网、娱乐、办公、导航等多种功能，极大提升了生活的便利性。\n- 随身携带方便，随时随地可使用。\n\n### 2. **拍照质量不断提升**\n- 现代智能手机（如iPhone、华为、三星等）搭载了高像素摄像头、光学防抖、AI算法、夜景模式等技术，拍照效果已接近甚至超越部分专业相机。\n- 支持多种拍摄模式（如人像、全景、延时摄影等），适合日常记录和创作。\n\n### 3. **电池续航能力提升**\n- 大容量电池（如4000mAh以上）和优化的系统管理（如省电模式、后台进程限制）使得多数手机可以满足一天的使用需求。\n- 快充技术（如65W、100W快充）大幅缩短充电时间，提升用户体验。\n\n### 4. **智能生态系统整合**\n- 与电脑、耳机、智能家居设备等无缝连接，形成完整的数字生态。\n\n---\n\n## 二、智能手机的缺点\n\n### 1. **电池续航受限**\n- 尽管电池容量增加，但高性能处理器、高刷新率屏幕、5G网络等仍会快速消耗电量。\n- 大部分手机仍需每天充电，尤其是重度使用者。\n- 长期使用后电池老化，续航能力下降。\n\n### 2. **拍照质量仍有局限**\n- 虽然硬件强大，但在极端环境下（如弱光、逆光、高速运动）仍不如专业相机。\n- 依赖软件算法增强的“美颜”或“HDR”可能造成照片失真或不自然。\n- 长焦镜头和光学变焦能力有限，无法完全替代专业望远镜式镜头。\n\n### 3. **隐私与安全问题**\n- 智能手机存储大量个人信息，存在被黑客攻击、数据泄露的风险。\n- 应用权限管理不当可能导致隐私泄露。\n\n### 4. **健康影响**\n- 长时间使用可能导致视力疲劳、颈椎问题、睡眠障碍等。\n- 过度依赖手机可能影响社交能力和专注力。\n\n---\n\n## 三、总结评价\n\n| 方面         | 优点                              | 缺点                                  |\n|--------------|-----------------------------------|---------------------------------------|\n| **电池续航** | 大容量电池 + 快充技术             | 续航仍受性能和使用习惯影响，电池老化   |\n| **拍照质量** | 高像素 + AI算法 + 多种模式        | 极端场景表现不足，依赖软件处理         |\n| **整体优势** | 便捷、多功能、智能化              | 依赖性强、隐私风险、健康隐患          |\n\n---\n\n## 四、未来发展趋势\n\n- **电池技术**：固态电池、无线充电、太阳能充电等新技术将提升续航和安全性。\n- **拍照技术**：多摄联动、光学变焦、AI图像处理将进一步提升成像质量。\n- **用户健康**：厂商正在开发护眼模式、使用提醒等功能，以减少负面影响。\n\n---\n\n如需根据特定品牌或型号（如iPhone、华为Mate系列、小米等）进行更具体的分析，也可以告诉我，我可以进一步展开。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 738, 'prompt_tokens': 26, 'total_tokens': 764, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'qwen-turbo', 'system_fingerprint': None, 'id': 'chatcmpl-19b97502-2e12-4ff3-b7f5-59691cd501c2', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--bf8845eb-0501-4035-8ab9-ef36113f486d-0' usage_metadata={'input_tokens': 26, 'output_tokens': 738, 'total_tokens': 764, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}
# <class 'langchain_core.messages.ai.AIMessage'>
