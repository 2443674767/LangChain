# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

# 前提：加载配置文件
dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DASHSCOPE_BASE_URL")

# 1、获取对话模型
chat_model = ChatOpenAI(
    # api_key=,
    # base_url=,
    model_name="qwen-turbo",
)

# 2、调用对话模型
response = chat_model.invoke("帮我解释一下什么是langchain?")

# 3、处理响应数据
# print(response)
print(response.content)
print(type(response))  #<class 'langchain_core.messages.ai.AIMessage'>
# Out:
# 当然可以！**LangChain** 是一个用于构建 **基于语言模型（LLM）的应用程序** 的框架或工具库。它可以帮助开发者更高效地集成和使用像 GPT、LLaMA、Bard 等大型语言模型，实现各种自然语言处理任务。
#
# ---
#
# ## 🧠 什么是 LangChain？
#
# **LangChain** 是一个开源的 Python 框架，专注于让开发者更容易地将语言模型（如 GPT、LLaMA 等）与外部数据源、工具和应用程序结合使用。它提供了一套统一的接口和工具，帮助你构建智能对话系统、聊天机器人、知识问答系统、自动化流程等。
#
# ---
#
# ## 📌 LangChain 的核心功能
#
# ### 1. **链式调用（Chains）**
# - 可以将多个语言模型的调用组合成一个“链条”。
# - 例如：先进行文本生成，再对结果进行总结，再做情感分析。
#
# ```python
# from langchain import LLMChain, PromptTemplate
# from langchain.llms import OpenAI
#
# llm = OpenAI(temperature=0)
# prompt = PromptTemplate(
#     input_variables=["product"],
#     template="What is a good name for a company that makes {product}?"
# )
# chain = LLMChain(llm=llm, prompt=prompt)
# response = chain.run("colorful socks")
# ```
#
# ### 2. **记忆（Memory）**
# - 让模型在多个交互中保持上下文信息。
# - 例如：用户问“我昨天提到的项目”，模型能记住之前的内容。
#
# ### 3. **数据连接（Data Connections）**
# - 支持将语言模型与数据库、API、文件等数据源连接起来。
# - 例如：从数据库中查询信息，再通过语言模型生成回答。
#
# ### 4. **工具集成（Tool Integration）**
# - 可以整合各种工具（如搜索、计算器、代码执行器等），增强语言模型的能力。
#
# ### 5. **代理（Agents）**
# - 允许语言模型根据任务自动选择合适的工具或方法。
# - 例如：如果用户问“今天天气如何？”，代理会自动调用天气 API。
#
# ---
#
# ## 🚀 为什么需要 LangChain？
#
# - **简化开发流程**：不需要从头开始处理所有逻辑，而是可以复用已有的组件。
# - **提高效率**：快速搭建应用原型，减少重复工作。
# - **扩展性强**：支持多种语言模型和工具，适合不同场景。
# - **社区活跃**：有大量文档、教程和社区支持。
#
# ---
#
# ## ✅ 适用场景
#
# - 聊天机器人（Chatbot）
# - 自动问答系统（Q&A System）
# - 个性化推荐系统
# - 文本摘要、翻译、内容生成
# - 数据分析与报告生成
# - 自动化客服系统
#
# ---
#
# ## 🧩 举个例子
#
# 假设你想做一个**智能客服系统**：
#
# 1. 用户输入：“我的订单什么时候到？”
# 2. LangChain 会：
#    - 从数据库中查询用户的订单状态
#    - 使用语言模型生成自然语言的回答
#    - 如果需要，调用物流 API 获取最新信息
#    - 最后返回给用户清晰的回答
#
# ---
#
# ## 📦 安装 LangChain
#
# 你可以通过 pip 安装 LangChain：
#
# ```bash
# pip install langchain
# ```
#
# 如果你要使用 OpenAI 的模型，还需要安装 `openai`：
#
# ```bash
# pip install openai
# ```
#
# ---
#
# ## 📘 更多资源
#
# - [LangChain 官方文档](https://python.langchain.com/)
# - [GitHub 仓库](https://github.com/hwchase17/langchain)
# - [教程和示例](https://github.com/hwchase17/langchain/tree/master/docs)
#
# ---
#
# 如果你有具体的使用场景或问题，也可以告诉我，我可以帮你进一步解释或写代码示例 😊
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
from langchain_core.messages import SystemMessage, HumanMessage

system_message = SystemMessage(content="你是一个英语教学方向的专家")
human_message = HumanMessage(content="帮我制定一个英语六级学习的计划")

messages = [system_message, human_message]

print(messages)
# Out:
# [SystemMessage(content='你是一个英语教学方向的专家', additional_kwargs={}, response_metadata={}), HumanMessage(content='帮我制定一个英语六级学习的计划', additional_kwargs={}, response_metadata={})]

# %%
response = chat_model.invoke(messages)
print(type(response))
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 当然可以！以下是一个为期**12周**的英语六级（CET-6）学习计划，适合基础中等、目标是通过考试的考生。这个计划结合了词汇、听力、阅读、写作和翻译的训练，帮助你全面提高英语能力。
#
# ---
#
# ## 📌 一、整体目标
#
# - 掌握高频词汇（约4000个）
# - 提高听力理解能力（包括短对话、长对话、讲座、新闻）
# - 熟悉阅读题型，提升快速阅读与信息提取能力
# - 掌握写作技巧，能写出结构清晰、语言流畅的作文
# - 提高翻译水平，掌握常见句型和表达方式
#
# ---
#
# ## 📅 二、12周学习计划（每周5天学习，2天休息）
#
# ### **第1-2周：打基础，熟悉题型**
#
# #### 每日学习时间：3小时（可灵活调整）
#
# | 时间 | 内容 |
# |------|------|
# | 9:00-10:00 | 听力训练（真题+模拟题） |
# | 10:15-11:15 | 阅读训练（选词填空 + 长篇阅读） |
# | 11:30-12:30 | 词汇记忆（每天50个单词，重点背高频词汇） |
# | 14:00-15:00 | 写作/翻译练习（每周写1篇作文，练1次翻译） |
# | 15:15-16:15 | 复习+错题整理 |
#
# #### 每周任务：
# - 完成1套听力真题
# - 完成2套阅读真题
# - 背完100个高频词汇
# - 写1篇作文 + 1次翻译练习
# - 整理一周错题并总结
#
# ---
#
# ### **第3-4周：强化听力和阅读**
#
# #### 每日学习时间：3.5小时
#
# | 时间 | 内容 |
# |------|------|
# | 9:00-10:00 | 听力训练（精听+跟读） |
# | 10:15-11:15 | 阅读训练（仔细阅读 + 匹配题） |
# | 11:30-12:30 | 词汇记忆（每天50个新词） |
# | 14:00-15:00 | 写作/翻译练习（每周写1篇作文，练1次翻译） |
# | 15:15-16:15 | 复习+错题整理 |
#
# #### 每周任务：
# - 完成2套听力真题
# - 完成3套阅读真题
# - 背完100个高频词汇
# - 写2篇作文 + 2次翻译练习
# - 整理错题并查漏补缺
#
# ---
#
# ### **第5-6周：突破写作和翻译**
#
# #### 每日学习时间：3.5小时
#
# | 时间 | 内容 |
# |------|------|
# | 9:00-10:00 | 听力训练（限时做题） |
# | 10:15-11:15 | 阅读训练（快速阅读 + 选择题） |
# | 11:30-12:30 | 词汇记忆（每天50个新词） |
# | 14:00-15:30 | 写作专项训练（模板+仿写） |
# | 15:45-16:15 | 翻译练习（每日1段） |
#
# #### 每周任务：
# - 完成2套听力真题
# - 完成3套阅读真题
# - 背完100个高频词汇
# - 写2篇作文 + 2次翻译练习
# - 整理错题并查漏补缺
#
# ---
#
# ### **第7-8周：综合提升与冲刺**
#
# #### 每日学习时间：4小时
#
# | 时间 | 内容 |
# |------|------|
# | 9:00-10:30 | 听力训练（全真模拟） |
# | 10:45-12:00 | 阅读训练（全真模拟） |
# | 12:15-13:15 | 词汇复习（回顾前几周内容） |
# | 14:00-15:30 | 写作/翻译专项训练（限时写作+翻译） |
# | 15:45-16:15 | 复习+错题整理 |
#
# #### 每周任务：
# - 完成2套全真模拟题
# - 完成2套听力+2套阅读+1套写作+1套翻译
# - 回顾所有词汇
# - 每天做1篇作文+1次翻译
#
# ---
#
# ### **第9-12周：全真模拟+查漏补缺**
#
# #### 每日学习时间：4-5小时
#
# | 时间 | 内容 |
# |------|------|
# | 9:00-10:30 | 全真模拟（听力+阅读） |
# | 10:45-12:00 | 全真模拟（写作+翻译） |
# | 12:15-13:15 | 错题分析+词汇复习 |
# | 14:00-15:30 | 写作/翻译专项训练 |
# | 15:45-16:15 | 复习+总结 |
#
# #### 每周任务：
# - 完成3套全真模拟题
# - 每天做1套听力+1套阅读+1篇作文+1次翻译
# - 查漏补缺，强化弱项
# - 总结高频考点和易错点
#
# ---
#
# ## 🧠 三、推荐资料
#
# | 类别 | 推荐资料 |
# |------|----------|
# | 词汇 | 《星火四级词汇》《考研英语词汇》 |
# | 听力 | 《大学英语六级听力真题详解》《新东方六级听力》 |
# | 阅读 | 《大学英语六级阅读真题详解》《星火六级阅读》 |
# | 写作 | 《大学英语六级写作范文100篇》《新东方六级写作》 |
# | 翻译 | 《大学英语六级翻译真题详解》《专八翻译》 |
# | 模拟题 | 《华研外语六级模拟题》《新东方六级模拟题》 |
#
# ---
#
# ## ✅ 四、学习建议
#
# 1. **坚持每天学习**，哪怕只学半小时。
# 2. **注重错题分析**，避免重复错误。
# 3. **多听多读**，培养语感。
# 4. **写作要模仿优秀范文**，积累句型和表达。
# 5. **翻译要注重准确性和地道表达**，避免直译。
#
# ---
#
# 如果你告诉我你的英语基础（比如目前的词汇量、是否通过四级、平时的学习时间等），我可以为你定制一个更具体的计划。需要的话，我也可以帮你制定每日具体的学习内容安排。

# %%
from langchain_core.messages import (
    AIMessage,
    HumanMessage,
    SystemMessage,
    ChatMessage
)

# 创建不同类型的消息
system_message = SystemMessage(content="你是一个专业的数据科学家")
human_message = HumanMessage(content="解释一下随机森林算法")
ai_message = AIMessage(content="随机森林是一种集成学习方法...")
custom_message = ChatMessage(role="analyst", content="补充一点关于超参数调优的信息")

print(system_message.content)
print(human_message.content)
print(ai_message.content)
print(custom_message.content)
# Out:
# 你是一个专业的数据科学家
# 解释一下随机森林算法
# 随机森林是一种集成学习方法...
# 补充一点关于超参数调优的信息

# %% [markdown]
# 多轮对话与上下文记忆

# %%
import os
import dotenv
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DASHSCOPE_BASE_URL")

chat_model = ChatOpenAI(
    model_name="qwen-turbo",
    temperature=0.7,# 1=创造力
    max_tokens=100,
)

# %%
from langchain_core.messages import SystemMessage, HumanMessage

sys_message = SystemMessage(
    content="我是一个人工智能的助手，我的名字叫小智",
)
human_message = HumanMessage(content="猫王是一只猫吗？")

messages = [sys_message, human_message]

#调用大模型，传入messages
response = chat_model.invoke(messages)
# print(response.content)


response1 = chat_model.invoke("你叫什么名字？")
print(response1.content)
# Out:
# 哈哈，这个问题问得真有趣！猫王其实不是一只猫哦，它是一位传奇人物——埃尔维斯·普雷斯利（Elvis Presley），被人们亲切地称为“猫王”。他是一位著名的美国歌手、演员，被誉为“摇滚乐之王”，对20世纪的音乐和流行文化产生了深远的影响。
#
# 不过，如果你真的有一只叫“猫王”的猫，那它一定是个非常特别的小家伙呢！你是不是也有一只可爱的小猫？可以跟我分享一下它的故事吗？😊
# 你好！我叫通义千问，是阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。你可以叫我Qwen。有什么问题或者需要帮助的地方吗？我会尽力为你提供支持和解答。

# %%
from langchain_core.messages import SystemMessage, HumanMessage

sys_message = SystemMessage(
    content="我是一个人工智能的助手，我的名字叫小智",
)
human_message = HumanMessage(content="猫王是一只猫吗？")
human_message1 = HumanMessage(content="你叫什么名字？")

messages = [sys_message, human_message,human_message1]

#调用大模型，传入messages
response = chat_model.invoke(messages)
print(response.content)
# Out:
# 我叫小智，是一只人工智能的助手。至于猫王，他可能是一只猫，也可能是一个名字，比如猫王可能是某个著名人物的昵称，比如摇滚歌手埃尔维斯·普雷斯利（Elvis Presley）的昵称之一。不过，如果在特定语境下，猫王确实指的是一只猫，那它就是一只猫。你想知道更多关于猫王的信息吗？

# %%
from langchain_core.messages import SystemMessage, HumanMessage

sys_message = SystemMessage(
    content="我是一个人工智能的助手，我的名字叫小智",
)
human_message = HumanMessage(content="猫王是一只猫吗？")

sys_message1 = SystemMessage(
    content="我可以做很多事情，有需要就找我吧",
)

human_message1 = HumanMessage(content="你叫什么名字？")

messages = [sys_message, human_message,sys_message1,human_message1]

#调用大模型，传入messages
response = chat_model.invoke(messages)
print(response.content)
# Out:
# 我是小智，一个AI助手。虽然我不是一只真正的猫，但我可以像猫王一样可爱和有趣！你有什么需要帮助的吗？

# %%
from langchain_core.messages import SystemMessage, HumanMessage

# 第1组
sys_message = SystemMessage(
    content="我是一个人工智能的助手，我的名字叫小智",
)
human_message = HumanMessage(content="猫王是一只猫吗？")

messages = [sys_message, human_message]

# 第2组
sys_message1 = SystemMessage(
    content="我可以做很多事情，有需要就找我吧",
)

human_message1 = HumanMessage(content="你叫什么名字？")

messages1 = [sys_message1,human_message1]

#调用大模型，传入messages
response = chat_model.invoke(messages)
# print(response.content)

response = chat_model.invoke(messages1)
print(response.content)
# Out:
# 我叫通义千问，是阿里巴巴集团旗下的通义实验室研发的超大规模语言模型。有什么我可以帮你的吗？

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="我是一个人工智能助手，我的名字叫小智"),
    HumanMessage(content="人工智能英文怎么说？"),
    AIMessage(content="AI"),
    HumanMessage(content="你叫什么名字"),
]

messages1 = [
    SystemMessage(content="我是一个人工智能助手，我的名字叫小智"),
    HumanMessage(content="很高兴认识你"),
    AIMessage(content="我也很高兴认识你"),
    HumanMessage(content="你叫什么名字"),
]

messages2 = [
    SystemMessage(content="我是一个人工智能助手，我的名字叫小智"),
    HumanMessage(content="人工智能英文怎么说？"),
    AIMessage(content="AI"),
    HumanMessage(content="你叫什么名字"),
]

chat_model.invoke(messages2)
# Out:
# AIMessage(content='我叫小智。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 46, 'total_tokens': 51, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'qwen-turbo', 'system_fingerprint': None, 'id': 'chatcmpl-33875582-6277-4b4d-a729-b68ac7630dea', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--c7aa0238-3f80-4f87-81d2-d6cbb25c0364-0', usage_metadata={'input_tokens': 46, 'output_tokens': 5, 'total_tokens': 51, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})

# %%
import os
import dotenv
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DASHSCOPE_BASE_URL")

chat_model = ChatOpenAI(
    model_name="qwen-turbo",
    temperature=0.7,# 1=创造力
    max_tokens=100,
)

# 创建消息
messages = [HumanMessage(content="你好，请介绍一下自己")]

# 非流式调用LLM获取响应
response = chat_model.invoke(messages)

# 打印响应内容
print(response)

# %%
import os
import dotenv
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DASHSCOPE_BASE_URL")

chat_model = ChatOpenAI(
    model_name="qwen-turbo",
    temperature=0.7,# 1=创造力
    max_tokens=100,
)

# 创建消息
messages = [HumanMessage(content="你好，请介绍一下自己")]

# print(type(chat_model.stream(messages)))

# 流式调用LLM获取响应
print("开始流式输出：")
for chunk in chat_model.stream(messages):
    # 逐个打印内容块
    print(chunk.content, end="", flush=True) # 刷新缓冲区 (无换行符，缓冲区未刷新，内容可能不会立即显示)

print("\n流式输出结束")
# Out:
# <class 'generator'>
# 开始流式输出：
# 你好！我是通义千问，由阿里巴巴集团旗下的阿里云研发的超大规模语言模型。我能够回答问题、创作文字、逻辑推理、编程等多种任务。我的目标是为用户提供帮助和便利。有什么我可以帮你的吗？
# 流式输出结束

# %%
import os
import dotenv
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DASHSCOPE_BASE_URL")

chat_model = ChatOpenAI(
    model_name="qwen-turbo",
    temperature=0.7,# 1=创造力
    max_tokens=100,
)

messages1 = [SystemMessage(content="你是一位乐于助人的智能小助手"),
             HumanMessage(content="请帮我介绍一下什么是机器学习"), ]

messages2 = [SystemMessage(content="你是一位乐于助人的智能小助手"),
             HumanMessage(content="请帮我介绍一下什么是AIGC"), ]

messages3 = [SystemMessage(content="你是一位乐于助人的智能小助手"),
             HumanMessage(content="请帮我介绍一下什么是大模型技术"), ]

messages = [messages1, messages2, messages3]

# 调用batch
response = chat_model.batch(messages)

print(response)
# Out:
# [AIMessage(content='你好！很高兴为你介绍什么是机器学习。\n\n**机器学习（Machine Learning，简称 ML）** 是人工智能（AI）的一个重要分支，它的核心目标是让计算机能够通过经验或数据自动学习和改进，而无需显式地进行编程。换句话说，机器学习就是让计算机“自己学会”如何完成任务。\n\n### 一、机器学习的基本概念\n\n在传统编程中，我们给计算机一个明确的指令（程序），然后输入数据，计算机按照这些指令处理数据并输出结果。  \n而在机器学习中，我们不是直接告诉计算机怎么做，而是给它一些**数据**，让它从这些数据中“学习”出规律或模式，然后用这个规律去解决新的问题。\n\n---\n\n### 二、机器学习的类型\n\n根据学习方式的不同，机器学习可以分为以下几类：\n\n#### 1. **监督学习（Supervised Learning）**\n- **特点**：有标签的数据（即每个样本都有正确的答案）。\n- **例子**：分类（如判断一封邮件是否是垃圾邮件）、回归（如预测房价）。\n- **常用算法**：线性回归、逻辑回归、支持向量机（SVM）、决策树、神经网络等。\n\n#### 2. **无监督学习（Unsupervised Learning）**\n- **特点**：没有标签的数据，模型需要自己发现数据中的结构。\n- **例子**：聚类（如将客户分成不同群体）、降维（如简化数据维度）。\n- **常用算法**：K均值聚类、主成分分析（PCA）等。\n\n#### 3. **半监督学习（Semi-supervised Learning）**\n- 介于监督和无监督之间，部分数据有标签，部分没有。\n\n#### 4. **强化学习（Reinforcement Learning）**\n- **特点**：通过试错来学习，通过奖励机制优化行为。\n- **例子**：训练机器人走路、AlphaGo（围棋AI）。\n- **常用方法**：Q-learning、深度强化学习（DRL）。\n\n---\n\n### 三、机器学习的一般流程\n\n1. **数据收集**：获取与问题相关的数据。\n2. **数据预处理**：清洗数据、处理缺失值、归一化等。\n3. **特征工程**：提取对模型有用的特征。\n4. **选择模型**：根据问题选择合适的算法。\n5. **训练模型**：用数据训练模型。\n6. **评估模型**：测试模型在新数据上的表现。\n7. **应用模型**：将训练好的模型用于实际问题。\n\n---\n\n### 四、机器学习的应用场景\n\n- **图像识别**：如人脸识别、医学影像分析。\n- **自然语言处理（NLP）**：如机器翻译、智能客服。\n- **推荐系统**：如淘宝、Netflix 的个性化推荐。\n- **金融风控**：如信用评分、欺诈检测。\n- **自动驾驶**：如特斯拉的自动驾驶系统。\n\n---\n\n### 五、简单例子说明\n\n假设你想让计算机识别猫和狗的照片：\n\n- **传统编程**：你手动写规则，比如“如果图片中有毛茸茸的动物，就判断为猫”。\n- **机器学习**：你给计算机很多带标签的猫和狗照片（比如“这是一只猫”、“这是一只狗”），然后让它自己学习“猫和狗有什么不同”。\n\n---\n\n如果你对某个具体领域感兴趣，比如“深度学习”、“Python实现机器学习”或者“机器学习在哪个行业应用最多”，我也可以进一步为你讲解哦！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 745, 'prompt_tokens': 32, 'total_tokens': 777, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'qwen-turbo', 'system_fingerprint': None, 'id': 'chatcmpl-1a68cb57-d3f3-4e9b-8544-d1fcdc1ebe15', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--fc8514d6-9891-4814-8060-7bbb2b3ed74a-0', usage_metadata={'input_tokens': 32, 'output_tokens': 745, 'total_tokens': 777, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), AIMessage(content='当然可以！AIGC 是 **AI-Generated Content** 的缩写，中文意思是“人工智能生成内容”。它是指利用人工智能技术（尤其是自然语言处理、深度学习等）来自动创作各种形式的内容，如文字、图片、音频、视频等。\n\n### AIGC 的主要特点：\n1. **自动化**：无需人工干预即可生成内容。\n2. **高效性**：可以在短时间内生成大量内容。\n3. **多样性**：可以生成不同风格、类型和用途的内容。\n4. **智能化**：能够根据用户需求进行个性化创作。\n\n### AIGC 的应用领域：\n- **文本生成**：如文章、新闻、小说、对话、邮件、代码等。例如，像我这样的 AI 语言模型就是用来生成文本的。\n- **图像生成**：如使用 DALL·E、Stable Diffusion 等工具生成图片。\n- **音频生成**：如语音合成、音乐创作等。\n- **视频生成**：如通过 AI 技术生成动画或视频内容。\n- **游戏内容生成**：如自动生成游戏场景、角色设定等。\n\n### AIGC 的意义：\nAIGC 的出现极大地提高了内容创作的效率，降低了创作门槛，使得更多人可以轻松地生成高质量的内容。同时，它也带来了新的挑战，比如版权问题、内容真实性、伦理问题等。\n\n如果你对某一种具体的 AIGC 技术感兴趣，比如文本生成或者图像生成，我可以进一步为你详细讲解哦！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 316, 'prompt_tokens': 33, 'total_tokens': 349, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'qwen-turbo', 'system_fingerprint': None, 'id': 'chatcmpl-2336f942-72d9-4060-a23d-e60b8b6ece30', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--a14a5ef0-1569-4e3b-b53c-877257ef35ab-0', usage_metadata={'input_tokens': 33, 'output_tokens': 316, 'total_tokens': 349, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), AIMessage(content='当然可以！很高兴为你介绍什么是**大模型技术**。\n\n---\n\n## 一、什么是大模型？\n\n“大模型”通常指的是**大规模语言模型（Large Language Model，简称 LLM）**，它是一种基于深度学习的机器学习模型，能够理解和生成自然语言文本。这类模型通常具有**海量的参数**（比如数十亿甚至上千亿个），并且通过大量的文本数据进行训练，从而具备强大的语言理解和生成能力。\n\n---\n\n## 二、大模型的核心特点\n\n1. **庞大的参数量**  \n   大模型通常包含数以亿计甚至万亿级别的参数，这些参数是模型在训练过程中学习到的“知识”。\n\n2. **强大的语言理解与生成能力**  \n   大模型可以理解人类的语言，并能根据输入内容生成高质量的文本，如回答问题、写文章、创作诗歌、翻译等。\n\n3. **多任务处理能力**  \n   一个大模型可以同时完成多种任务，例如问答、摘要、对话、代码生成等，而不需要为每个任务单独训练一个模型。\n\n4. **预训练 + 微调机制**  \n   大模型通常先进行**预训练**，使用大量文本数据学习语言规律；然后通过**微调**，针对特定任务进行优化，提高效果。\n\n---\n\n## 三、大模型的应用场景\n\n- **智能客服**：自动回复用户的问题。\n- **内容生成**：撰写文章、故事、邮 ...

# %%
import time

def call_model():
    # 模拟同步API调用
    print("开始调用模型...")
    time.sleep(5)  # 模拟调用等待,单位：秒
    print("模型调用完成。")

def perform_other_tasks():
    # 模拟执行其他任务
    for i in range(5):
        print(f"执行其他任务 {i + 1}")
        time.sleep(1)  # 单位：秒

def main():
    start_time = time.time()
    call_model()
    perform_other_tasks()
    end_time = time.time()
    total_time = end_time - start_time
    return f"总共耗时：{total_time}秒"

# 运行同步任务并打印完成时间
main_time = main()
print(main_time)
# Out:
# 开始调用模型...
# 模型调用完成。
# 执行其他任务 1
# 执行其他任务 2
# 执行其他任务 3
# 执行其他任务 4
# 执行其他任务 5
# 总共耗时：10.00438141822815秒

# %%
import asyncio
import time

async def async_call(llm):
    await asyncio.sleep(5)  # 模拟异步操作
    print("异步调用完成")

async def perform_other_tasks():
    await asyncio.sleep(5)  # 模拟异步操作
    print("其他任务完成")

async def run_async_tasks():
    start_time = time.time()
    await asyncio.gather(
        async_call(None),  # 示例调用，使用None模拟LLM对象
        perform_other_tasks()
    )
    end_time = time.time()
    return f"总共耗时：{end_time - start_time}秒"

# # 正确运行异步任务的方式
# if __name__ == "__main__":
#     # 使用 asyncio.run() 来启动异步程序
#     result = asyncio.run(run_async_tasks())
#     print(result)


# 在 Jupyter 单元格中直接调用
result = await run_async_tasks()
print(result)
# Out:
# 异步调用完成
# 其他任务完成
# 总共耗时：5.001101016998291秒
